# %% [markdown]
# #### 任务2.3

# %% [markdown]
# 在同一画布中，绘制蓝领（blue-collar）与学生（student）的产品
# 购买情况饼图，并设定饼图的标签，显示产品购买情况的占比。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['font.sans-serif'] = ['SimHei']
color = sns.color_palette()

# %%
df = pd.read_excel('./result1_3.xlsx')

# %%
df['job']
# Out:
# 0         3
# 1         7
# 2         0
# 3         7
# 4         0
#          ..
# 30440    10
# 30441     1
# 30442     5
# 30443     9
# 30444     5
# Name: job, Length: 30445, dtype: int64

# %%
cond_blue = df['job'] == 4
cond_stu = df['job'] == 10

# %%
df_stu = df[cond_stu]

# %%
df_blue = df[cond_blue]

# %%
df_blue = df_blue.reset_index()
df_blue
# Out:
#       index  user_id  age  job  marital  education  default  housing  loan  \
# 0        40       40   24    4        1          3        0        0     0
# 1        41       41   27    4        0          4        0        1     0
# 2        44       45   24    4        1          3        0        0     0
# 3        52       53   25    4        1          4        0        0     0
# 4        61       62   20    4        1          4        0        0     0
# ...     ...      ...  ...  ...      ...        ...      ...      ...   ...
# 2305  30332    30330   14    4        1          4        0        1     0
# 2306  30392    30390   41    4        1          4        0        1     0
# 2307  30400    30398   16    4        1          4        0        1     0
# 2308  30412    30410    9    4        2          4        0        1     0
# 2309  30430    30428   23    4        0          4        0        1     0
#
#       contact  month  day_of_week  duration  poutcome  y
# ...

# %%
df_blue_2 = df_blue.iloc[:,1:]

# %%
df_blue_2
# Out:
#       user_id  age  job  marital  education  default  housing  loan  contact  \
# 0          40   24    4        1          3        0        0     0        1
# 1          41   27    4        0          4        0        1     0        1
# 2          45   24    4        1          3        0        0     0        1
# 3          53   25    4        1          4        0        0     0        1
# 4          62   20    4        1          4        0        0     0        1
# ...       ...  ...  ...      ...        ...      ...      ...   ...      ...
# 2305    30330   14    4        1          4        0        1     0        0
# 2306    30390   41    4        1          4        0        1     0        0
# 2307    30398   16    4        1          4        0        1     0        0
# 2308    30410    9    4        2          4        0        1     0        0
# 2309    30428   23    4        0          4        0        1     0        0
#
# ...

# %%
df_blue_2
# Out:
#       user_id  age  job  marital  education  default  housing  loan  contact  \
# 0          40   24    4        1          3        0        0     0        1
# 1          41   27    4        0          4        0        1     0        1
# 2          45   24    4        1          3        0        0     0        1
# 3          53   25    4        1          4        0        0     0        1
# 4          62   20    4        1          4        0        0     0        1
# ...       ...  ...  ...      ...        ...      ...      ...   ...      ...
# 2305    30330   14    4        1          4        0        1     0        0
# 2306    30390   41    4        1          4        0        1     0        0
# 2307    30398   16    4        1          4        0        1     0        0
# 2308    30410    9    4        2          4        0        1     0        0
# 2309    30428   23    4        0          4        0        1     0        0
#
# ...

# %%
num_blue_0 = df_blue_2[(df_blue_2['y'] == 0)]
display(num_blue_0.shape)
# Out:
# (2024, 14)

# %%
num_blue_1 = df_blue_2[(df_blue_2['y'] == 1)]
display(num_blue_1.shape)
# Out:
# (286, 14)

# %%
proportion_blue_0 = num_blue_0.shape[0]/df_blue_2.shape[0]
proportion_blue_1 = num_blue_1.shape[0]/df_blue_2.shape[0]
print(proportion_blue_0,proportion_blue_1,proportion_blue_0+proportion_blue_1)
# Out:
# 0.8761904761904762 0.12380952380952381 1.0

# %%
sizes = [proportion_blue_0,proportion_blue_1]  # 每一块的比例
labels = '0','1'
colors = ['yellowgreen', 'gold']
explode = (0.05, 0.2,)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）
_ = plt.pie(sizes,explode=explode,labels=labels,colors=colors, autopct='%1.2f%%',shadow=True,)
_ = plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.title('蓝领(blue-collar)的产品购买情况')
# Out:
# Text(0.5, 1.0, '蓝领(blue-collar)的产品购买情况')

# %%
df_stu = df_stu.reset_index()

# %%
df_stu_2 = df_stu.iloc[:,1:]

# %%
df_stu_2
# Out:
#      user_id  age  job  marital  education  default  housing  loan  contact  \
# 0         11   13   10        1          0        0        0     0        1
# 1         50   16   10        1          3        0        0     0        1
# 2         77   26   10        2          4        0        1     0        1
# 3        111   18   10        1          2        0        0     0        1
# 4        207   26   10        2          4        0        0     0        1
# ..       ...  ...  ...      ...        ...      ...      ...   ...      ...
# 733    30301   19   10        1          0        0        1     0        0
# 734    30391   24   10        1          3        0        0     0        0
# 735    30394   37   10        1          2        0        1     0        1
# 736    30396   41   10        1          4        0        1     0        0
# 737    30439   12   10        2          3        0        1     0        0
#
#      month  day_of_week  duration  poutcome  y
# ...

# %%
num_stu_0 = df_stu_2[(df_stu_2['y'] == 0)]
display(num_stu_0.shape)
# Out:
# (612, 14)

# %%
num_stu_1 = df_stu_2[(df_stu_2['y'] == 1)]
display(num_stu_1.shape)
# Out:
# (126, 14)

# %%
proportion_stu_0 = num_stu_0.shape[0]/df_stu_2.shape[0]
proportion_stu_1 = num_stu_1.shape[0]/df_stu_2.shape[0]
print(proportion_stu_0,proportion_stu_1,proportion_stu_0+proportion_stu_1)
# Out:
# 0.8292682926829268 0.17073170731707318 1.0

# %%
sizes = [proportion_stu_0,proportion_stu_1]  # 每一块的比例
labels = '0','1'
colors = ['lightskyblue', 'lightcoral']
explode = (0.05, 0.02,)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）
_ = plt.pie(sizes,explode=explode,labels=labels,colors=colors, autopct='%1.2f%%',shadow=True,)
_ = plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.title('学生(student)的产品购买情况')
# Out:
# Text(0.5, 1.0, '学生(student)的产品购买情况')
